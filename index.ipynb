# %%
import pandas as pd
import numpy as np
pd.read_csv('j1.csv')
# Out:
#             Full Name  Gender Date of Birth         University_Name  \
# 0        Norma Fisher  Female    10/29/1954    University of Jaffna
# 1      Jorge Sullivan  Female     9/16/1932  University of Kelaniya
# 2     Elizabeth Woods  Female      5/9/1956    University of Jaffna
# 3        Susan Wagner  Female     11/4/1938     Rajarata University
# 4    Peter Montgomery    Male     4/21/1964     Rajarata University
# ..                ...     ...           ...                     ...
# 995   Howard Anderson    Male     9/18/2017  University of Moratuwa
# 996      Jacob Rivera  Female      4/2/1988  University of Moratuwa
# 997    Lori Rodriguez  Female     6/30/1965    University of Jaffna
# 998      Whitney Diaz  Female     2/17/2017  University of Moratuwa
# 999      Mary Alvarez  Female      4/9/1912  University of Kelaniya
#
#     Current Academic Year  Cumulative Grade Point Average (GPA)  \
# 0                     2nd                                  3.48
# ...

# %%
data=pd.read_csv('j1.csv')

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# Display top 5 Rows in My Dataset

# %%
data.head()
# Out:
#           Full Name  Gender Date of Birth         University_Name  \
# 0      Norma Fisher  Female    10/29/1954    University of Jaffna
# 1    Jorge Sullivan  Female     9/16/1932  University of Kelaniya
# 2   Elizabeth Woods  Female      5/9/1956    University of Jaffna
# 3      Susan Wagner  Female     11/4/1938     Rajarata University
# 4  Peter Montgomery    Male     4/21/1964     Rajarata University
#
#   Current Academic Year  Cumulative Grade Point Average (GPA)  \
# 0                   2nd                                  3.48
# 1                   4th                                  2.58
# 2                   1st                                  2.79
# 3                   4th                                  2.01
# 4                   2nd                                  3.31
#
#   Preferred Learning Style  Average Weekly Study Hours  Attendance Regularity  \
# 0              Kinesthetic                       20.80                      6
# ...

# %% [markdown]
# Check Last 5 Rows in My Dataset

# %%
data.tail()
# Out:
#            Full Name  Gender Date of Birth         University_Name  \
# 995  Howard Anderson    Male     9/18/2017  University of Moratuwa
# 996     Jacob Rivera  Female      4/2/1988  University of Moratuwa
# 997   Lori Rodriguez  Female     6/30/1965    University of Jaffna
# 998     Whitney Diaz  Female     2/17/2017  University of Moratuwa
# 999     Mary Alvarez  Female      4/9/1912  University of Kelaniya
#
#     Current Academic Year  Cumulative Grade Point Average (GPA)  \
# 995                   1st                                  2.18
# 996                   3rd                                  3.73
# 997                   2nd                                  3.57
# 998                   4th                                  3.04
# 999                   3rd                                  2.51
#
#     Preferred Learning Style  Average Weekly Study Hours  \
# 995              Kinesthetic                       12.34
# 996              Kinesthetic                       11.77
# ...

# %% [markdown]
# Find Shape of Our Dataset

# %%
data.shape
# Out:
# (1000, 14)

# %%
print("Number of Rows",data.shape[0])
print("Number of column",data.shape[1])
# Out:
# Number of Rows 1000
# Number of column 14

# %% [markdown]
# Information about My Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Full Name                                    1000 non-null   object
#  1   Gender                                       1000 non-null   object
#  2   Date of Birth                                1000 non-null   object
#  3   University_Name                              1000 non-null   object
#  4   Current Academic Year                        1000 non-null   object
#  5   Cumulative Grade Point Average (GPA)         1000 non-null   float64
#  6   Preferred Learning Style                     1000 non-null   object
#  7   Average Weekly Study Hours                   1000 non-null   float64
#  8   Attendance Regularity                        1000 non-null   int64
# ...

# %% [markdown]
# Check Null Values in My Dataset

# %%
data.isnull().sum()
# Out:
# Full Name                                      0
# Gender                                         0
# Date of Birth                                  0
# University_Name                                0
# Current Academic Year                          0
# Cumulative Grade Point Average (GPA)           0
# Preferred Learning Style                       0
# Average Weekly Study Hours                     0
# Attendance Regularity                          0
# Parental Education Level                       0
# Monthly Household Income                       0
# Participation in Extracurricular Activities    0
# Social Media Spending Time                     0
# Sleeping Hours                                 0
# dtype: int64

# %% [markdown]
# OverAll Statistic in My Dataset

# %%
data.describe()
# Out:
#        Cumulative Grade Point Average (GPA)  Average Weekly Study Hours  \
# count                           1000.000000                 1000.000000
# mean                               3.012380                   17.610950
# std                                0.584174                    7.377428
# min                                2.010000                    5.010000
# 25%                                2.500000                   10.887500
# 50%                                3.040000                   17.600000
# 75%                                3.520000                   24.032500
# max                                4.000000                   29.990000
#
#        Attendance Regularity  Social Media Spending Time  Sleeping Hours
# count            1000.000000                 1000.000000     1000.000000
# mean                5.500000                    2.422730        7.068600
# std                 2.879634                    1.432091        1.695431
# ...

# %% [markdown]
# EDA

# %%
data.columns
# Out:
# Index(['Full Name', 'Gender', 'Date of Birth', 'University_Name',
#        'Current Academic Year', 'Cumulative Grade Point Average (GPA)',
#        'Preferred Learning Style', 'Average Weekly Study Hours',
#        'Attendance Regularity', 'Parental Education Level',
#        'Monthly Household Income',
#        'Participation in Extracurricular Activities',
#        'Social Media Spending Time', 'Sleeping Hours'],
#       dtype='object')

# %% [markdown]
# Howmany Students got Cumulative Grade Point Average (GPA)

# %%
data['Cumulative Grade Point Average (GPA)'].unique()
# Out:
# array([3.48, 2.58, 2.79, 2.01, 3.31, 3.43, 3.32, 3.99, 3.05, 2.66, 3.01,
#        3.21, 3.57, 2.48, 2.29, 3.25, 3.34, 3.63, 2.46, 3.47, 3.84, 2.59,
#        2.19, 2.6 , 3.38, 3.56, 2.83, 3.74, 3.5 , 2.57, 2.52, 3.71, 2.62,
#        3.53, 3.89, 3.8 , 2.81, 2.43, 2.85, 3.44, 2.77, 3.51, 3.69, 2.97,
#        2.11, 2.44, 2.88, 2.03, 3.95, 3.77, 2.53, 2.25, 2.27, 3.82, 3.75,
#        2.75, 3.35, 3.  , 3.39, 3.07, 2.65, 3.19, 2.26, 3.12, 3.16, 2.1 ,
#        3.76, 2.28, 2.3 , 2.12, 2.04, 3.88, 2.89, 2.92, 3.67, 2.78, 2.56,
#        2.63, 3.72, 2.18, 2.07, 3.06, 3.58, 2.54, 2.13, 2.14, 3.79, 3.17,
#        3.92, 3.7 , 2.84, 3.6 , 2.05, 2.87, 3.08, 2.93, 2.49, 2.82, 2.51,
#        2.61, 3.94, 2.74, 3.13, 3.49, 3.45, 3.73, 2.69, 2.16, 2.33, 2.86,
#        3.68, 3.41, 3.15, 3.59, 3.22, 3.98, 3.55, 2.15, 2.96, 2.73, 2.45,
#        2.41, 3.29, 2.35, 3.65, 2.2 , 3.3 , 3.61, 3.09, 2.09, 3.18, 3.2 ,
#        3.93, 2.72, 2.94, 3.9 , 3.86, 3.83, 2.68, 2.39, 2.47, 3.46, 3.62,
# ...

# %%
data['Cumulative Grade Point Average (GPA)'].value_counts()
# Out:
# Cumulative Grade Point Average (GPA)
# 2.18    11
# 3.65    11
# 3.32    11
# 3.73    10
# 3.38    10
#         ..
# 2.32     1
# 3.54     1
# 2.36     1
# 3.24     1
# 3.11     1
# Name: count, Length: 198, dtype: int64

# %% [markdown]
# Data Preprocessing

# %%
data.head()
# Out:
#           Full Name  Gender Date of Birth         University_Name  \
# 0      Norma Fisher  Female    10/29/1954    University of Jaffna
# 1    Jorge Sullivan  Female     9/16/1932  University of Kelaniya
# 2   Elizabeth Woods  Female      5/9/1956    University of Jaffna
# 3      Susan Wagner  Female     11/4/1938     Rajarata University
# 4  Peter Montgomery    Male     4/21/1964     Rajarata University
#
#   Current Academic Year  Cumulative Grade Point Average (GPA)  \
# 0                   2nd                                  3.48
# 1                   4th                                  2.58
# 2                   1st                                  2.79
# 3                   4th                                  2.01
# 4                   2nd                                  3.31
#
#   Preferred Learning Style  Average Weekly Study Hours  Attendance Regularity  \
# 0              Kinesthetic                       20.80                      6
# ...

# %%
data=data.drop(['Full Name'],axis=1)

# %%
data.head()
# Out:
#    Gender Date of Birth         University_Name Current Academic Year  \
# 0  Female    10/29/1954    University of Jaffna                   2nd
# 1  Female     9/16/1932  University of Kelaniya                   4th
# 2  Female      5/9/1956    University of Jaffna                   1st
# 3  Female     11/4/1938     Rajarata University                   4th
# 4    Male     4/21/1964     Rajarata University                   2nd
#
#    Cumulative Grade Point Average (GPA) Preferred Learning Style  \
# 0                                  3.48              Kinesthetic
# 1                                  2.58                   Visual
# 2                                  2.79                   Visual
# 3                                  2.01                 Auditory
# 4                                  3.31                 Auditory
#
#    Average Weekly Study Hours  Attendance Regularity Parental Education Level  \
# ...

# %% [markdown]
# Encoding the Categorical Columns

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
data['Gender']=data['Gender'].map({'Male':0,'Female':1})

# %%
data.head()
# Out:
#    Gender Date of Birth         University_Name Current Academic Year  \
# 0       1    10/29/1954    University of Jaffna                   2nd
# 1       1     9/16/1932  University of Kelaniya                   4th
# 2       1      5/9/1956    University of Jaffna                   1st
# 3       1     11/4/1938     Rajarata University                   4th
# 4       0     4/21/1964     Rajarata University                   2nd
#
#    Cumulative Grade Point Average (GPA) Preferred Learning Style  \
# 0                                  3.48              Kinesthetic
# 1                                  2.58                   Visual
# 2                                  2.79                   Visual
# 3                                  2.01                 Auditory
# 4                                  3.31                 Auditory
#
#    Average Weekly Study Hours  Attendance Regularity Parental Education Level  \
# ...

# %%
data=data.drop(['Date of Birth','Preferred Learning Style','Parental Education Level','Monthly Household Income'],axis=1)

# %%
data.head()
# Out:
#    Gender         University_Name Current Academic Year  \
# 0       1    University of Jaffna                   2nd
# 1       1  University of Kelaniya                   4th
# 2       1    University of Jaffna                   1st
# 3       1     Rajarata University                   4th
# 4       0     Rajarata University                   2nd
#
#    Cumulative Grade Point Average (GPA)  Average Weekly Study Hours  \
# 0                                  3.48                       20.80
# 1                                  2.58                       22.05
# 2                                  2.79                       10.41
# 3                                  2.01                       24.10
# 4                                  3.31                       21.13
#
#    Attendance Regularity Participation in Extracurricular Activities  \
# 0                      6                                          No
# 1                      1                                          No
# ...

# %%
data['University_Name'].unique()
# Out:
# array(['University of Jaffna', 'University of Kelaniya',
#        'Rajarata University', 'University of Moratuwa',
#        'University of Colombo', 'Eastern University',
#        'University of Ruhuna', 'University of Peradeniya',
#        'Sabaragamuwa University'], dtype=object)

# %%
data['University_Name']=data['University_Name'].map({'University of Jaffna':0,'University of Kelaniya':1,'Rajarata University':2,'University of Moratuwa':3,'University of Colombo':4,'Eastern University':5,'University of Ruhuna':6,'University of Peradeniya':7,'Sabaragamuwa University':8})

# %%
data.head()
# Out:
#    Gender  University_Name Current Academic Year  \
# 0       1                0                   2nd
# 1       1                1                   4th
# 2       1                0                   1st
# 3       1                2                   4th
# 4       0                2                   2nd
#
#    Cumulative Grade Point Average (GPA)  Average Weekly Study Hours  \
# 0                                  3.48                       20.80
# 1                                  2.58                       22.05
# 2                                  2.79                       10.41
# 3                                  2.01                       24.10
# 4                                  3.31                       21.13
#
#    Attendance Regularity Participation in Extracurricular Activities  \
# 0                      6                                          No
# 1                      1                                          No
# ...

# %%
data['Current Academic Year'].unique()
# Out:
# array(['2nd', '4th', '1st', '3rd'], dtype=object)

# %%
data['Current Academic Year']=data['Current Academic Year'].map({'1st':0,'2nd':1,'3rd':2,'4th':3})

# %%
data.head()
# Out:
#    Gender  University_Name  Current Academic Year  \
# 0       1                0                      1
# 1       1                1                      3
# 2       1                0                      0
# 3       1                2                      3
# 4       0                2                      1
#
#    Cumulative Grade Point Average (GPA)  Average Weekly Study Hours  \
# 0                                  3.48                       20.80
# 1                                  2.58                       22.05
# 2                                  2.79                       10.41
# 3                                  2.01                       24.10
# 4                                  3.31                       21.13
#
#    Attendance Regularity Participation in Extracurricular Activities  \
# 0                      6                                          No
# 1                      1                                          No
# ...

# %%
data['Participation in Extracurricular Activities'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['Participation in Extracurricular Activities']=data['Participation in Extracurricular Activities'].map({'No':0,'Yes':1})

# %%
data.head()
# Out:
#    Gender  University_Name  Current Academic Year  \
# 0       1                0                      1
# 1       1                1                      3
# 2       1                0                      0
# 3       1                2                      3
# 4       0                2                      1
#
#    Cumulative Grade Point Average (GPA)  Average Weekly Study Hours  \
# 0                                  3.48                       20.80
# 1                                  2.58                       22.05
# 2                                  2.79                       10.41
# 3                                  2.01                       24.10
# 4                                  3.31                       21.13
#
#    Attendance Regularity  Participation in Extracurricular Activities  \
# 0                      6                                            0
# 1                      1                                            0
# ...

# %% [markdown]
# Store Feature Matrix in X and Y(Target variable)

# %%
data.columns
# Out:
# Index(['Gender', 'University_Name', 'Current Academic Year',
#        'Cumulative Grade Point Average (GPA)', 'Average Weekly Study Hours',
#        'Attendance Regularity', 'Participation in Extracurricular Activities',
#        'Social Media Spending Time', 'Sleeping Hours'],
#       dtype='object')

# %%
y=data["Cumulative Grade Point Average (GPA)"]
X=data.drop(['Cumulative Grade Point Average (GPA)'],axis=1)

# %% [markdown]
# Splitting Dataset Into the Training Set and Test Set

# %%
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=42)

# %%
data.head()
# Out:
#    Gender  University_Name  Current Academic Year  \
# 0       1                0                      1
# 1       1                1                      3
# 2       1                0                      0
# 3       1                2                      3
# 4       0                2                      1
#
#    Cumulative Grade Point Average (GPA)  Average Weekly Study Hours  \
# 0                                  3.48                       20.80
# 1                                  2.58                       22.05
# 2                                  2.79                       10.41
# 3                                  2.01                       24.10
# 4                                  3.31                       21.13
#
#    Attendance Regularity  Participation in Extracurricular Activities  \
# 0                      6                                            0
# 1                      1                                            0
# ...

# %% [markdown]
# Import The Model

# %%
threshold = 2.5
y_train_binary = (y_train > threshold).astype(int)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm 
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
threshold = 2.5
y_train_binary = (y_train > threshold).astype(int)

# %%
lr=LogisticRegression()
lr.fit(X_train,y_train_binary)
# Out:
# LogisticRegression()

# %%
svm=svm.SVC()
svm.fit(X_train,y_train_binary)
# Out:
# SVC()

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,y_train_binary)
# Out:
# KNeighborsClassifier()

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train_binary)
# Out:
# DecisionTreeClassifier()

# %%
rf=RandomForestClassifier()
rf.fit(X_train,y_train_binary)
# Out:
# RandomForestClassifier()

# %%
gb=GradientBoostingClassifier()
gb.fit(X_train,y_train_binary)
# Out:
# GradientBoostingClassifier()

# %% [markdown]
# Prediction on Test Data

# %%
y_pred1=lr.predict(X_test)
y_pred2=svm.predict(X_test)
y_pred3=knn.predict(X_test)
y_pred4=dt.predict(X_test)
y_pred5=rf.predict(X_test)
y_pred6=gb.predict(X_test)

# %% [markdown]
# Evaluating the Algorithms

# %%
from sklearn.metrics import accuracy_score

# %%
# Example of converting continuous predictions into binary class labels
threshold = 0.5  # Define a threshold to convert probabilities into binary predictions

y_pred_binary1 = (y_pred1 > threshold).astype(int)  # Convert to binary labels for Logistic Regression
y_pred_binary2 = (y_pred2 > threshold).astype(int)  # Convert to binary labels for SVM
y_pred_binary3 = (y_pred3 > threshold).astype(int)  # Convert to binary labels for KNN
y_pred_binary4 = (y_pred4 > threshold).astype(int)  # Convert to binary labels for Decision Tree
y_pred_binary5 = (y_pred5 > threshold).astype(int)  # Convert to binary labels for Random Forest
y_pred_binary6 = (y_pred6 > threshold).astype(int)  # Convert to binary labels for Gradient Boosting

# %%
y_test_binary = (y_test > threshold).astype(int)  # Convert to binary labels

# %%
score1=accuracy_score(y_test_binary,y_pred_binary1)
score2=accuracy_score(y_test_binary,y_pred_binary2)
score3=accuracy_score(y_test_binary,y_pred_binary3)
score4=accuracy_score(y_test_binary,y_pred_binary4)
score5=accuracy_score(y_test_binary,y_pred_binary5)
score6=accuracy_score(y_test_binary,y_pred_binary6)

# %%
print(score1,score2,score3,score4,score5,score6)
# Out:
# 1.0 1.0 0.8766666666666667 0.7366666666666667 0.96 0.92

# %%
final_data=pd.DataFrame({'Models':['LogisticRegression','SuportedVectorMachine','KNeighborsClassifier','DecisionTreeClassifier','RandomForestClassifier','GradientBoostingClassifier'],
                         'Accuracy':[score1*100,
                                score2*100,
                                score3*100,
                                score4*100,
                                score5*100,
                                score6*100]})

# %%
print(final_data)
# Out:
#                        Models    Accuracy
# 0          LogisticRegression  100.000000
# 1       SuportedVectorMachine  100.000000
# 2        KNeighborsClassifier   87.666667
# 3      DecisionTreeClassifier   73.666667
# 4      RandomForestClassifier   96.000000
# 5  GradientBoostingClassifier   92.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming final_data is a DataFrame containing 'Models' and 'Accuracy' columns

plt.figure(figsize=(10, 6))  # Adjust figure size as needed

sns.barplot(x=final_data['Models'], y=final_data['Accuracy'])
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming final_data is a DataFrame containing 'Models' and 'Accuracy' columns

plt.figure(figsize=(10, 6))  # Adjust figure size as needed

sns.barplot(x=final_data['Models'], y=final_data['Accuracy'], palette='husl')  # Set palette to 'husl' for different colors
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %% [markdown]
# Prediction On New Data

# %%
data.head()
# Out:
#    Gender  University_Name  Current Academic Year  \
# 0       1                0                      1
# 1       1                1                      3
# 2       1                0                      0
# 3       1                2                      3
# 4       0                2                      1
#
#    Cumulative Grade Point Average (GPA)  Average Weekly Study Hours  \
# 0                                  3.48                       20.80
# 1                                  2.58                       22.05
# 2                                  2.79                       10.41
# 3                                  2.01                       24.10
# 4                                  3.31                       21.13
#
#    Attendance Regularity  Participation in Extracurricular Activities  \
# 0                      6                                            0
# 1                      1                                            0
# ...

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# Assuming you have already trained the RandomForestClassifier model (rf) and it is available

# Create a DataFrame for the new data
new_data = pd.DataFrame({
    'Gender': [0],
    'University_Name': [1],
    'Current Academic Year': [3],
    'Average Weekly Study Hours': [22.30],
    'Attendance Regularity': [5],
    'Participation in Extracurricular Activities': [1],
    'Social Media Spending Time': [1.50],
    'Sleeping Hours': [7.71]
})

# Assuming you have trained the RandomForestClassifier model (rf) earlier in your code

# Ensure that the RandomForestClassifier model (rf) is fitted before making predictions
if hasattr(rf, 'estimators_') and len(rf.estimators_) > 0:
    # Model is already fitted
    rf.fit(X_train, y_train)
    predictions = rf.predict(new_data)
    print("Predicted GPA:", predictions[0])
else:
    print("RandomForestClassifier model is not fitted yet. Please fit the model before making predictions.")
# Out:
# RandomForestClassifier model is not fitted yet. Please fit the model before making predictions.

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

# Assuming you have your training data X_train and y_train

# Train the RandomForestRegressor model
rf = RandomForestRegressor()
rf.fit(X_train, y_train)

# Now the model is fitted, you can proceed to make predictions

# Create a DataFrame for the new data
new_data = pd.DataFrame({
    'Gender': [1],
    'University_Name': [2],
    'Current Academic Year': [1],
    'Average Weekly Study Hours': [1.30],
    'Attendance Regularity': [1],
    'Participation in Extracurricular Activities': [0],
    'Social Media Spending Time': [11.50],
    'Sleeping Hours': [11.71]
})

# Make predictions using the trained RandomForestRegressor model
predictions = rf.predict(new_data)

# Print the predicted GPA
print("Predicted GPA:", predictions[0])
# Out:
# Predicted GPA: 2.8480000000000008

# %% [markdown]
# Save Model Using Joblib

# %%
import joblib

# %%
joblib.dump(rf,'model_campus_placement')
# Out:
# ['model_campus_placement']

# %%
model=joblib.load('model_campus_placement')

# %%
model.predict(new_data)
# Out:
# array([2.848])
